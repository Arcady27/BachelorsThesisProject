# %%
import numpy as np
import pandas as pd
import csv
from __future__ import unicode_literals
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def russian_freq(f):
    if f == '1hour':
        return '1 час'
    if f == '10minutes':
        return '10 минут'
    if f == '1day':
        return '1 день'

# %%
INSTRUMENTS = ['GAZP','LKOH','SPFB.RTS','SBER','SPFB.MIX']
INSTRUMENTS = ['GE','NASDAQ.AAPL','XOM','NASDAQ.GOOG','C','DSX','NQ-100-FUT']
periods = ['10minutes','1hour','1day']
depths = [3,6]
for period in periods:
    FREQUENCY = period
    for depth in depths:
        res = np.fromfile('results/results_' + INSTRUMENT + '_' + FREQUENCY + '_'+ str(depth) +  '.txt',dtype = np.float32)
        res = res.reshape(res.shape[0]/6,6)
        res_ens = np.fromfile('results/results_ensemble_' + INSTRUMENT + '_' + FREQUENCY + '_'+ str(depth) +  '.txt',dtype = np.float32)
        res_ens = res_ens.reshape(res_ens.shape[0]/6,6)
        print period,' ',depth,' train: ',res[res.shape[0]-1,4], ' test: ',res[res.shape[0]-1,5],\
        ' -- ensemble --  train: ', res_ens[res_ens.shape[0]-1,0],' test: ', res_ens[res_ens.shape[0]-1,1]
# Out:
# 10minutes   3  train:  1326.51  test:  1571.97  -- ensemble --  train:  929.919  test:  1157.8
# 10minutes   6  train:  1136.6  test:  1414.48  -- ensemble --  train:  750.126  test:  959.592
# 1hour   3  train:  650.14  test:  856.354  -- ensemble --  train:  551.812  test:  658.731
# 1hour   6  train:  472.345  test:  155.043  -- ensemble --  train:  471.337  test:  529.121
# 1day   3  train:  197.485  test:  5.45311  -- ensemble --  train:  275.683  test:  316.304
# 1day   6  train:  154.63  test:  90.6268  -- ensemble --  train:  248.585  test:  273.371

# %%
#INSTRUMENT = 'GAZP'
FREQUENCY = '1hour'
depth = 6
res = np.fromfile('results/results_' + INSTRUMENT + '_' + FREQUENCY + '_'+ str(depth) +  '.txt',dtype = np.float32)
res = res.reshape(res.shape[0]/6,6) 

train_genetic, = plt.plot(res[:,4],'blue',label='')
test_genetic, = plt.plot(res[:,5],'red')

if res[0,0] > res[0,2]:
    train_not_genetic, = plt.plot(res[:,0],'blue',ls='--')
else:
    train_not_genetic, = plt.plot(res[:,2],'blue',ls='--')

if res[0,1] > res[0,3]:
    test_not_genetic, =plt.plot(res[:,1],'red',ls='--')
else:
    test_not_genetic, =plt.plot(res[:,3],'red',ls='--')


plt.title("Инструмент: %s;  Периодичность: %s; Глубина деревьев: %d" % (INSTRUMENT,russian_freq(FREQUENCY),depth), y=1.08)
plt.xlabel('поколение')
plt.ylabel('результат, у.е')


plt.legend([train_genetic,test_genetic,train_not_genetic,test_not_genetic], ['Ген. алгоритм на обучающей выборке',
                                                                             'Ген. алгоритм на тестовой выборке',
                                                                             'Бенчмарк на обучающей выборке',
                                                                             'Бенчмарк на тестовой выборке'],
          bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#plt.show()

# %%
res_ens = np.fromfile('results/results_ensemble_' + INSTRUMENT + '_' + FREQUENCY + '_' + str(depth)+'.txt',dtype = np.float32)
res_ens = res_ens.reshape(res_ens.shape[0]/6,6) 
train_genetic, = plt.plot(res_ens[:,0],'blue')
test_genetic, = plt.plot(res_ens[:,1],'red')

# if res_ens[0,0] > res_ens[0,2]:
#     train_first, = plt.plot(res_ens[:,0],'blue',ls='--')
# else:
#     train_first, = plt.plot(res_ens[:,2],'blue',ls='--')

# if res_ens[0,1] > res_ens[0,3]:
#     test_first, =plt.plot(res_ens[:,1],'red',ls='--')
# else:
#     test_first, =plt.plot(res_ens[:,3],'red',ls='--')

train_first, = plt.plot(res_ens[:,4],'blue',ls='--')
test_first, = plt.plot(res_ens[:,5],'red',ls='--')
    
plt.title("Инструмент: %s;  Периодичность: %s; Глубина деревьев: %d" % (INSTRUMENT,russian_freq(FREQUENCY),depth), y=1.08)
plt.xlabel('поколение')
plt.ylabel('результат, у.е')


plt.legend([train_genetic,test_genetic,train_first,test_first], ['Ансамбль на обучающей выборке',
                                                                             'Ансамбль на тестовой выборке',
                                                                             'Лучшее дерево на обучающей выборке',
                                                                             'Лучшее дерево на тестовой выборке'],
          bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
PATH = 'data/'
INSTRUMENT = 'US2.AAPL'
DAY_START = '150129'
DAY_END = '160129'
filename = PATH + INSTRUMENT + '_' + DAY_START + '_' + DAY_END + '.txt'

# %%
filename
# Out:
# 'days/US2.AAPL_150129_160129.txt'

# %%
data=np.genfromtxt('features/' + INSTRUMENT + '_' + DAY_START + '_' + DAY_END + '_features.txt', delimiter=',')

# %%
data = pd.read_csv(filename)
del data['<TICKER>']
del data['<PER>'] 
del data['<DATE>'] 
del data['<TIME>'] 

data.columns = ['open','high','low','close','vol']
size = data.shape[0]

# %%
data
# Out:
#        open     high      low    close     vol
# 0   116.330  116.430  116.190  116.280   47984
# 1   116.290  116.380  116.010  116.080   48833
# 2   116.090  116.120  115.850  115.980   62568
# 3   115.990  116.630  115.950  116.620   53294
# 4   116.630  116.660  116.250  116.260   44106
# 5   116.210  116.450  116.190  116.450   43979
# 6   116.450  116.560  116.260  116.270   50674
# 7   116.270  116.300  115.990  116.030   49444
# 8   116.050  116.180  115.970  116.040   37057
# 9   116.030  116.150  116.020  116.140   40146
# 10  116.140  116.140  115.870  115.890   64595
# 11  115.880  115.880  115.625  115.730   41155
# 12  115.740  115.880  115.710  115.840   26946
# 13  115.850  115.860  115.740  115.850   28396
# 14  115.810  115.880  115.740  115.880   43345
# 15  115.880  116.050  115.830  115.845   44970
# 16  115.840  115.990  115.760  115.840   27972
# 17  115.830  115.855  115.560  115.570   76805
# 18  115.590  116.090  115.570  116.090   69439
# 19  116.090  116.130  115.810  115.840   31290
# 20  115.850  115.900  115.710  115.790   46359
# 21  115.790  115.990  115.790  115.930   28315
# 22  115.930  116.270  115.920  116.270   99174
# 23  116.280  116.390  116.280  116.320   32219
# 24  116.330  116.510  116.320  116.500   41576
# 25  116.490  116.690  116.480  116.670   49354
# 26  116.680  116.690  116.420  116.450   39479
# 27  116.430  116.890  116.430  116.880   60716
# 28  116.880  116.990  116.850  116.945   64603
# 29  116.960  116.990  116.920  116.950   29928
# 30  116.940  116.940  116.780  116.800   49313
# 31  116.800  116.900  116.750  116.900   37753
# 32  116.900  117.130  116.870  117.110  112478
# 33  117.140  117.220  117.100  117.180   82990
# 34  117.180  117.250  117.160  117.190   53054
# 35  117.230  117.300  117.135  117.210   41531
# 36  117.200  117.210  116.920  116.980   44296
# 37  117.010  117.215  116.960  117.210   21222
# 38  117.220  117.300  117.210  117.220   35943
# 39  117.220  117.230  116.960  117.090   41717
# 40  117.080  117.180  117.040  117.160   22813
# 41  117.150  117.150  116.910  117.000   23949
# 42  117.010  117.010  116.960  116.990   29105
# 43  116.980  117.000  116.880  116.910   26036
# 44  116.910  116.910  116.810  116.900   25750
# 45  116.910  116.910  116.810  116.880   27269
# 46  116.890  117.050  116.890  117.030   30386
# 47  117.030  117.150  116.955  117.120   36492
# 48  117.160  117.270  117.160  117.250   24293
# 49  117.250  117.290  117.150  117.160   50484
# 50  117.160  117.230  117.140  117.220   21899
# 51  117.220  117.280  117.170  117.180   26877
# 52  117.170  117.190  117.120  117.140   17200
# 53  117.150  117.180  117.000  117.040   32996
# 54  117.040  117.040  116.895  116.990   26999
# 55  117.000  117.140  116.990  117.070   23602
# 56  117.075  117.085  117.025  117.040   15619
# 57  117.060  117.080  116.940  117.020   16291
# 58  117.050  117.230  117.050  117.230   33086
# 59  117.240  117.300  117.220  117.270   57786
#         ...      ...      ...      ...     ...
#
# [94487 rows x 5 columns]

# %%
# %%timeit
data['vol'][1000]
# Out:
# The slowest run took 22.11 times longer than the fastest. This could mean that an intermediate result is being cached
# 100000 loops, best of 3: 5.97 µs per loop

# %%
data.close[30:40]
# Out:
# 30    116.80
# 31    116.90
# 32    117.11
# 33    117.18
# 34    117.19
# 35    117.21
# 36    116.98
# 37    117.21
# 38    117.22
# 39    117.09
# Name: close, dtype: float64

# %%
from collections import Counter,deque

def calc_features():
    periods = [10,60]

    prices = [deque([]) for i in xrange(len(periods))]
    sum_prices = [0.0 for i in xrange(len(periods))]
    highs = [Counter({}) for i in xrange(len(periods))]
    lows = [Counter({}) for i in xrange(len(periods))]
    
    for p in periods:
        data['PROC_'+str(p)] = 0.0 #price rate of change
        data['VROC_'+str(p)] = 0.0 #volume rate of change
        data['MOM_'+str(p)] = 0.0 #momentum
        data['ABT_'+str(p)] = 0.0 #acceleration between times
        data['OBV_'+str(p)] = 0.0 #on balance volume
        data['NATR_'+str(p)] = 0.0 #normalized average true range
        
        #oscillators
        
        data['STOCH_'+str(p)] = 0.0 #stochastics
        data['F%K_'+str(p)] = 0.0 #fast stochastics
        data['S%K_'+str(p)] = 0.0 #slow stochastics
        data['S%D_'+str(p)] = 0.0 #slow slow stochastics
        
        data['EPV_' + str(p)] = 0.0 #ex-post volatility
        data['B%_'+str(p)] = 0.0 #bollinger bands percent
        data['BWIDTH_'+str(p)] = 0.0 #bollinger bands bandwidth
        data['WILLR_'+str(p)] = 0.0 #williams r
        
        #help values
        data['TR_'+str(p)] = 0.0 #true range
        
        
    data['PVT'] = 0.0 #price volume trend
    data['ADL'] = 0.0 #accumulated disitribution
    data['ADO'] = 0.0 #accumulated disitribution oscillator
    data['PPO'] = 0.0 #percent price oscillator
    data['MACD'] = 0.0 #moving average convergence-divergence


    for i in xrange(size): 
        if i%1000==0:
            print i
        smas = np.zeros((len(periods),),dtype=np.float32)
        for j in xrange(len(periods)):
            
            t = periods[j]
            s = str(t)
            
            close = data.close[i]
            close_prev = 0.0
            if i>=1:
                close_prev = data.close[i-1]         
            open = data.open[i]
            high = data.high[i]
            low = data.low[i]
            vol = data.vol[i]
            
            sma = np.mean(data.close[i-t:i+1])
            smas[j]=sma
            std = np.std(data.close[i-t:i+1])
            highest_high = np.max(data.high[i-t:i+1])
            lowest_low = np.min(data.low[i-t:i+1])
            
            data['TR_'+s][i] = np.max([high - low, high - close_prev, close_prev - low])
            if i>=t:
                
                data['PROC_'+s][i] = ((data.close[i-t] - close) / close) * 100
                data['VROC_'+s][i] = ((data.vol[i-t] - vol) / vol) * 100
                data['MOM_'+s][i] = data.close[i-t] - close          
                data['ABT_'+s][i] = data['MOM_'+s][i-t] - data['MOM_'+s][i]
                data['NATR_'+s][i] = np.mean(data['TR_' + s][i-t:i+1]) / close
                
                data['WILLR_'+s][i] = -100*((highest_high - close) / (highest_high - lowest_low))

                data['OBV_'+s][i] = data['OBV_'+s][i-1] + vol * np.sign(close - close_prev)
                
                data['STOCH_'+s][i] = ((close - lowest_low) / (highest_high - lowest_low))*100
                data['F%K_'+s][i] = np.mean(data['STOCH_'+s][i-t:i+1])
                data['S%K_'+s][i] = np.mean(data['F%K_'+s][i-3:i+1])
                data['S%D_'+s][i] = np.mean(data['S%K_'+s][i-3:i+1])
                
                data['EPV_'+s][i] = std / np.sqrt(t)
                
                middle_band = sma
                upper_band = middle_band + 2*std
                lower_band = middle_band - 2*std 
            
                data['B%_'+s][i] = (close - lower_band) / (upper_band - lower_band)
                data['BWIDTH_'+s][i] = upper_band - lower_band

        if i >= 1:
            data['PVT'][i] = data['PVT'][i-1] + vol * ((close - close_prev) / close_prev) 

        data['ADL'][i] += vol * ((close - low) - (high - close)) / (high - low)
        data['ADO'][i] += 100 * ((high - open) - (close - low)) / ((high - low) * 2)
        data['PPO'][i] = ((smas[0] - smas[1]) / smas[1]) * 100
        data['MACD'][i] = smas[0] - smas[1]
        
    print data.mean(axis=0)

# %%
for i in xrange(data.shape[1]):
    print np.mean(data[:,i])
# Out:
# -30649.6162522
# 110.728997732
# -0.677389587171
# 0.755723524876
# 0.117669336194
# 0.00228505239874
# 46.3003155136
# 0.00202535798575
# 2.36540476468e-05
# 0.000805447648883
# -48.9613681954
# 23168219.6793
# 51.0280443088
# 51.0238504562
# 51.0226237651
# 51.0214866192
# 396.54299073
# 0.499946868596
# 5015.91616352
# 0.013898933938
# 62.9732899508
# 0.0125613576471
# 6.97450442918e-05
# 0.000803829129933
# -48.906225128
# 22785536.1763
# 51.0302725261
# 51.0053810686
# 51.0042682326
# 51.0031742813
# 933.369940754
# 0.499682264195
# 28919.4098911
# 0.0567110361637
# 93.379478343
# 0.0519972588822
# 0.00377221205033
# 0.000801935377354
# -48.5062936807
# 22590848.6051
# 51.2397024693
# 51.1217408977
# 51.1202668799
# 51.1187936537
# 1852.07021156
# 0.498729744949
# 114768.593366
# 114768.593366

# %%
calc_features()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# open             119.574486
# high             119.617778
# low              119.528586
# close            119.573499
# vol             9782.749225
# PROC_10            0.002285
# VROC_10           -3.196207
# MOM_10             0.002025
# ABT_10             0.000024
# OBV_10      -1627984.678220
# NATR_10            0.000805
# STOCH_10          51.028046
# F%K_10            51.023853
# S%K_10            51.022626
# S%D_10            51.021489
# EPV_10             0.027801
# B%_10              0.498395
# BWIDTH_10          0.351657
# WILLR_10         -48.961370
# TR_10              0.095412
# PROC_60            0.013899
# VROC_60           15.190449
# MOM_60             0.012561
# ABT_60             0.000070
# OBV_60      -2010668.181221
# NATR_60            0.000804
# STOCH_60          51.030273
# F%K_60            51.005382
# S%K_60            51.004269
# S%D_60            51.003175
# EPV_60             0.028267
# B%_60              0.495683
# BWIDTH_60          0.875829
# WILLR_60         -48.906226
# TR_60              0.095412
# PVT           -30649.616252
# ADL              110.959189
# ADO               -0.678798
# PPO               -0.004773
# MACD              -0.005280
# dtype: float64

# %%
close
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-4536a917c692> in <module>()
# ----> 1 close
#
# NameError: name 'close' is not defined

# %%
import cProfile
cProfile.run('calc_features()')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
#          174079891 function calls (173323995 primitive calls) in 198.967 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1   12.741   12.741  198.967  198.967 <ipython-input-209-e9c7325ea576>:3(calc_features)
#         1    0.000    0.000  198.967  198.967 <string>:1(<module>)
#    188974    0.153    0.000    0.255    0.000 __init__.py:119(iteritems)
#    377948    0.367    0.000    0.611    0.000 __init__.py:138(itervalues)
#       376    0.002    0.000    0.017    0.000 __init__.py:265(dumps)
#        94    0.001    0.000    0.001    0.000 __init__.py:52(create_string_buffer)
#    188974    0.214    0.000    2.432    0.000 _methods.py:15(_amax)
#   1700766    1.816    0.000   10.806    0.000 _methods.py:23(_sum)
#   3023658    1.514    0.000    1.514    0.000 _weakrefset.py:70(__contains__)
#   3023623    2.642    0.000    4.599    0.000 abc.py:128(__instancecheck__)
#        94    0.001    0.000    0.001    0.000 attrsettr.py:35(__getattr__)
#         4    0.000    0.000    0.000    0.000 collections.py:438(__init__)
#         4    0.000    0.000    0.000    0.000 collections.py:501(update)
#    755908    0.403    0.000   12.780    0.000 common.py:111(isnull)
#    755908    1.486    0.000   12.377    0.000 common.py:128(_isnull_new)
#   4157518    2.413    0.000    7.696    0.000 common.py:1544(_values_from_object)
#    755896    1.100    0.000    1.100    0.000 common.py:1616(_possibly_castable)
#        35    0.000    0.000    0.001    0.000 common.py:1641(_possibly_cast_to_datetime)
#    755896    0.734    0.000    2.577    0.000 common.py:1742(_is_bool_indexer)
#    377948    0.594    0.000    0.732    0.000 common.py:1774(ensure_float)
#         8    0.000    0.000    0.000    0.000 common.py:1986(_asarray_tuplesafe)
#    755896    5.678    0.000    7.315    0.000 common.py:199(_isnull_ndarraylike)
#        35    0.000    0.000    0.000    0.000 common.py:2039(is_bool)
#   3023619    1.656    0.000    7.875    0.000 common.py:2043(is_integer)
#   1984262    1.094    0.000    1.798    0.000 common.py:2047(is_float)
#        35    0.000    0.000    0.000    0.000 common.py:2083(is_datetime64_dtype)
#        35    0.000    0.000    0.000    0.000 common.py:2103(is_timedelta64_dtype)
#        35    0.000    0.000    0.000    0.000 common.py:2160(_is_sequence)
#   2267704    1.425    0.000    2.811    0.000 common.py:58(_check)
#        35    0.000    0.000    0.001    0.000 common.py:848(_infer_dtype_from_scalar)
#       376    0.001    0.000    0.001    0.000 encoder.py:119(__init__)
#       376    0.001    0.000    0.015    0.000 encoder.py:241(encode)
#       376    0.005    0.000    0.013    0.000 encoder.py:270(iterencode)
#      2632    0.004    0.000    0.007    0.000 encoder.py:41(encode_basestring)
#        94    0.000    0.000    0.000    0.000 encoder.py:51(replace)
#   2645636    4.547    0.000   12.169    0.000 frame.py:1635(__getitem__)
#   2645636    2.337    0.000    4.344    0.000 frame.py:1660(_getitem_column)
#        12    0.000    0.000    0.000    0.000 frame.py:1862(_box_item_values)
#        12    0.000    0.000    0.000    0.000 frame.py:1869(_box_col_values)
#        35    0.000    0.000    0.043    0.001 frame.py:1874(__setitem__)
#        35    0.000    0.000    0.000    0.000 frame.py:1928(_ensure_valid_index)
#        35    0.000    0.000    0.042    0.001 frame.py:1954(_set_item)
#        35    0.001    0.000    0.030    0.001 frame.py:1995(_sanitize_column)
#    377948    1.359    0.000   17.054    0.000 fromnumeric.py:2048(amax)
#    188974    0.411    0.000   13.213    0.000 fromnumeric.py:2132(amin)
#    188974    0.497    0.000   16.315    0.000 fromnumeric.py:2632(mean)
#    188974    0.507    0.000   20.162    0.000 fromnumeric.py:2718(std)
#        35    0.000    0.000    0.020    0.001 fromnumeric.py:347(repeat)
#        35    0.000    0.000    0.020    0.001 fromnumeric.py:38(_wrapit)
#   2645636    1.517    0.000    2.006    0.000 generic.py:1001(_get_item_cache)
#        12    0.000    0.000    0.000    0.000 generic.py:1014(_set_as_cached)
#        35    0.000    0.000    0.000    0.000 generic.py:1061(_clear_item_cache)
#        35    0.000    0.000    0.011    0.000 generic.py:1067(_set_item)
#    661440    0.218    0.000    0.218    0.000 generic.py:1080(_check_setitem_copy)
#    755896    1.179    0.000    1.396    0.000 generic.py:1785(__finalize__)
#   1889740    4.374    0.000   16.031    0.000 generic.py:1801(__getattr__)
#        24    0.000    0.000    0.000    0.000 generic.py:1817(__setattr__)
#    566922    0.884    0.000   41.884    0.000 generic.py:3478(stat_func)
#    188974    0.352    0.000   18.705    0.000 generic.py:3546(var)
#    188974    0.832    0.000   19.655    0.000 generic.py:3563(std)
#   1889740    0.932    0.000    1.738    0.000 generic.py:358(_info_axis)
#    755908    1.764    0.000    1.764    0.000 generic.py:88(__init__)
#        94    0.000    0.000    0.001    0.000 hmac.py:116(hexdigest)
#        94    0.000    0.000    0.000    0.000 hmac.py:27(__init__)
#       376    0.000    0.000    0.001    0.000 hmac.py:80(update)
#        94    0.001    0.000    0.001    0.000 hmac.py:85(copy)
#        94    0.000    0.000    0.000    0.000 hmac.py:97(_current)
#        90    0.000    0.000    0.001    0.000 index.py:1009(get_loc)
#   1417305    2.432    0.000    9.632    0.000 index.py:1019(get_value)
#         4    0.000    0.000    0.001    0.000 index.py:1588(insert)
#    755896    2.691    0.000    7.874    0.000 index.py:1659(__new__)
#   1511792    0.205    0.000    0.205    0.000 index.py:1691(inferred_type)
#    755912    0.199    0.000    0.199    0.000 index.py:1700(is_all_dates)
#    755912    0.888    0.000    0.888    0.000 index.py:182(_reset_identity)
#    755939    1.721    0.000    2.568    0.000 index.py:186(view)
#    755896    0.385    0.000    0.470    0.000 index.py:205(_coerce_to_ndarray)
#    755912    0.887    0.000    1.988    0.000 index.py:220(__array_finalize__)
#         4    0.000    0.000    0.000    0.000 index.py:231(copy)
#         8    0.000    0.000    0.000    0.000 index.py:314(_set_names)
#    755900    0.397    0.000    0.586    0.000 index.py:3522(_ensure_index)
#         8    0.000    0.000    0.000    0.000 index.py:392(values)
#         4    0.000    0.000    0.000    0.000 index.py:409(is_unique)
#   1511792    1.036    0.000    1.241    0.000 index.py:413(is_integer)
#    755896    1.011    0.000    7.065    0.000 index.py:449(_validate_slicer)
#    755896    0.362    0.000    0.783    0.000 index.py:465(_convert_slice_indexer_getitem)
#    755896    2.865    0.000   15.151    0.000 index.py:472(_convert_slice_indexer)
#   2267688    1.141    0.000    6.055    0.000 index.py:476(validate)
#   1511792    0.657    0.000    3.618    0.000 index.py:491(is_int)
#         8    0.000    0.000    0.000    0.000 index.py:558(_engine)
#         8    0.000    0.000    0.000    0.000 index.py:561(<lambda>)
#   4536323    3.747    0.000    4.221    0.000 index.py:604(__contains__)
#    755939    4.494    0.000   27.037    0.000 index.py:615(__getitem__)
#    755904    7.589    0.000   16.288    0.000 index.py:98(__new__)
#        35    0.000    0.000    0.000    0.000 indexing.py:1334(_convert_to_index_sliceable)
#        31    0.000    0.000    0.000    0.000 internals.py:1201(should_store)
#    755912    0.347    0.000    0.347    0.000 internals.py:142(set_ref_locs)
#       146    0.000    0.000    0.000    0.000 internals.py:151(set_ref_items)
#       795    0.000    0.000    0.001    0.000 internals.py:180(__contains__)
#    755912    2.090    0.000    4.267    0.000 internals.py:1945(make_block)
#        35    0.000    0.000    0.000    0.000 internals.py:2060(shape)
#        12    0.000    0.000    0.000    0.000 internals.py:2063(<genexpr>)
#        35    0.000    0.000    0.000    0.000 internals.py:2066(ndim)
#         4    0.000    0.000    0.000    0.000 internals.py:2072(_set_axis)
#         4    0.000    0.000    0.000    0.000 internals.py:2085(set_axis)
#        31    0.000    0.000    0.000    0.000 internals.py:210(dtype)
#         4    0.000    0.000    0.000    0.000 internals.py:2101(_reset_ref_locs)
#         4    0.000    0.000    0.000    0.000 internals.py:2118(_rebuild_ref_locs)
#         8    0.000    0.000    0.000    0.000 internals.py:2132(_set_ref_locs)
#    756234    0.283    0.000    0.283    0.000 internals.py:2240(_get_items)
#    755896    0.725    0.000    1.167    0.000 internals.py:2314(__len__)
#        12    0.000    0.000    0.001    0.000 internals.py:2867(get)
#        12    0.000    0.000    0.000    0.000 internals.py:293(get)
#        35    0.000    0.000    0.011    0.000 internals.py:2962(set)
#        31    0.000    0.000    0.009    0.000 internals.py:2975(_set_item)
#        31    0.007    0.000    0.007    0.000 internals.py:300(set)
#         4    0.000    0.000    0.001    0.000 internals.py:3028(insert)
#         4    0.000    0.000    0.000    0.000 internals.py:3060(set_items_norename)
#         4    0.000    0.000    0.000    0.000 internals.py:3155(_add_new_block)
#        43    0.000    0.000    0.002    0.000 internals.py:3185(_find_block)
#        43    0.000    0.000    0.000    0.000 internals.py:3191(_check_have)
#    755908    2.516    0.000    7.552    0.000 internals.py:3572(__init__)
#   3590506    1.925    0.000    4.078    0.000 internals.py:3703(values)
#    755912    1.376    0.000    1.872    0.000 internals.py:53(__init__)
#       284    0.000    0.000    0.001    0.000 iostream.py:102(_check_mp_mode)
#        94    0.001    0.000    0.002    0.000 iostream.py:123(_flush_from_subprocesses)
#        94    0.002    0.000    0.046    0.000 iostream.py:151(flush)
#       190    0.002    0.000    0.050    0.000 iostream.py:207(write)
#        94    0.000    0.000    0.001    0.000 iostream.py:238(_flush_buffer)
#        94    0.000    0.000    0.000    0.000 iostream.py:247(_new_buffer)
#       378    0.000    0.000    0.001    0.000 iostream.py:93(_is_master_process)
#        94    0.000    0.000    0.001    0.000 iostream.py:96(_is_master_thread)
#       376    0.001    0.000    0.019    0.000 jsonapi.py:31(dumps)
#        94    0.000    0.000    0.000    0.000 jsonutil.py:75(date_default)
#    566922    0.397    0.000    0.741    0.000 nanops.py:111(_get_fill_value)
#    566922    2.410    0.000   17.305    0.000 nanops.py:134(_get_values)
#    944870    0.831    0.000    1.206    0.000 nanops.py:180(_na_ok_dtype)
#    566922    0.458    0.000    0.635    0.000 nanops.py:185(_view_if_needed)
#    566922    0.565    0.000    0.826    0.000 nanops.py:191(_wrap_results)
#    188974    0.793    0.000   11.427    0.000 nanops.py:237(nanmean)
#    188974    4.202    0.000   13.633    0.000 nanops.py:292(nanvar)
#    944870    0.628    0.000    1.287    0.000 nanops.py:31(check)
#    188974    1.026    0.000   10.932    0.000 nanops.py:325(nanmin)
#    188974    1.118    0.000   11.338    0.000 nanops.py:354(nanmax)
#    377948    1.572    0.000   31.760    0.000 nanops.py:36(_f)
#   1322818    1.076    0.000    2.363    0.000 nanops.py:39(<genexpr>)
#    188974    0.772    0.000    1.825    0.000 nanops.py:503(_get_counts)
#    377948    1.478    0.000    3.470    0.000 nanops.py:512(_maybe_null_out)
#    566922    0.711    0.000    1.621    0.000 nanops.py:599(_ensure_numeric)
#    755896    2.593    0.000   50.329    0.000 nanops.py:61(f)
#   1700825    1.988    0.000    2.474    0.000 numeric.py:1810(isscalar)
#        86    0.000    0.000    0.000    0.000 numeric.py:392(asarray)
#        35    0.000    0.000    0.000    0.000 numeric.py:462(asanyarray)
#        94    0.000    0.000    0.001    0.000 poll.py:77(poll)
#        94    0.000    0.000    0.000    0.000 py3compat.py:12(no_code)
#   1417305    1.004    0.000    2.863    0.000 series.py:1021(values)
#   2173201    1.254    0.000    3.473    0.000 series.py:1032(get_values)
#    755908    6.267    0.000   25.963    0.000 series.py:126(__init__)
#    755896    1.781    0.000   59.353    0.000 series.py:2031(_reduce)
#        12    0.000    0.000    0.000    0.000 series.py:229(from_array)
#    755896    0.216    0.000    0.216    0.000 series.py:239(_constructor)
#    755896    3.498    0.000    6.709    0.000 series.py:2490(_sanitize_array)
#    755896    0.717    0.000    1.816    0.000 series.py:2503(_try_cast)
#    755908    1.847    0.000    2.583    0.000 series.py:254(_set_axis)
#    755908    0.537    0.000    0.537    0.000 series.py:276(_set_subtyp)
#    755896    0.565    0.000    2.279    0.000 series.py:348(__len__)
#    755896    6.592    0.000   77.988    0.000 series.py:482(_slice)
#   1417305    2.214    0.000   12.441    0.000 series.py:489(__getitem__)
#    661409    0.607    0.000    5.163    0.000 series.py:591(__setitem__)
#    661409    1.590    0.000    4.556    0.000 series.py:642(_set_with_engine)
#    755896    1.148    0.000   79.136    0.000 series.py:702(__getslice__)
#        94    0.000    0.000    0.002    0.000 session.py:206(msg_header)
#        94    0.000    0.000    0.000    0.000 session.py:211(extract_header)
#        94    0.000    0.000    0.007    0.000 session.py:452(msg_id)
#        94    0.001    0.000    0.010    0.000 session.py:504(msg_header)
#        94    0.001    0.000    0.011    0.000 session.py:507(msg)
#        94    0.001    0.000    0.003    0.000 session.py:526(sign)
#        94    0.001    0.000    0.024    0.000 session.py:541(serialize)
#        94    0.002    0.000    0.040    0.000 session.py:600(send)
#       376    0.001    0.000    0.019    0.000 session.py:94(<lambda>)
#        35    0.000    0.000    0.001    0.000 shape_base.py:60(atleast_2d)
#        94    0.001    0.000    0.003    0.000 socket.py:289(send_multipart)
#        94    0.000    0.000    0.000    0.000 threading.py:1152(currentThread)
#        94    0.000    0.000    0.000    0.000 threading.py:983(ident)
#      1222    0.001    0.000    0.001    0.000 traitlets.py:420(__get__)
#       190    0.000    0.000    0.001    0.000 utf_8.py:15(decode)
#        94    0.003    0.000    0.003    0.000 uuid.py:101(__init__)
#        94    0.000    0.000    0.000    0.000 uuid.py:197(__str__)
#        94    0.002    0.000    0.006    0.000 uuid.py:546(uuid4)
#       190    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#    377948    0.352    0.000    2.715    0.000 {any}
#        94    0.002    0.000    0.002    0.000 {built-in method now}
#    755900    1.250    0.000    1.250    0.000 {function copy at 0x7fdab556cb18}
#         4    0.000    0.000    0.000    0.000 {function update at 0x7fdab5675f50}
#   5102349    4.087    0.000    6.075    0.000 {function view at 0x7fdab556c848}
#  13606488    5.254    0.000    5.254    0.000 {getattr}
#    944964    0.533    0.000    0.534    0.000 {hasattr}
#   4536323    0.474    0.000    0.474    0.000 {hash}
#  28164067    9.882    0.000   17.292    0.000 {isinstance}
#   8692941    2.292    0.000    2.292    0.000 {issubclass}
#        35    0.000    0.000    0.000    0.000 {iter}
# 5481245/4725349    1.245    0.000    2.253    0.000 {len}
#        94    0.000    0.000    0.000    0.000 {locals}
#        94    0.001    0.000    0.001    0.000 {map}
#        94    0.000    0.000    0.000    0.000 {max}
#       321    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#    189009    0.620    0.000    0.620    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       411    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        94    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#       282    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#        94    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        94    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#       190    0.001    0.000    0.001    0.000 {method 'decode' of 'str' objects}
#        94    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       376    0.001    0.000    0.001    0.000 {method 'encode' of 'unicode' objects}
#       188    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#    377948    0.860    0.000    0.860    0.000 {method 'fill' of 'numpy.generic' objects}
#   2645730    0.488    0.000    0.488    0.000 {method 'get' of 'dict' objects}
#        90    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas.index.IndexEngine' objects}
#   1417305    1.328    0.000    1.328    0.000 {method 'get_value' of 'pandas.index.IndexEngine' objects}
#        94    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        94    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#        94    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        94    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#    188974    0.067    0.000    0.067    0.000 {method 'iteritems' of 'dict' objects}
#    377948    0.140    0.000    0.140    0.000 {method 'itervalues' of 'dict' objects}
#       376    0.000    0.000    0.000    0.000 {method 'join' of 'unicode' objects}
#   1889740   11.208    0.000   11.208    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        35    0.020    0.001    0.020    0.001 {method 'repeat' of 'numpy.ndarray' objects}
#      1974    0.001    0.000    0.001    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#       658    0.002    0.000    0.002    0.000 {method 'send' of 'zmq.backend.cython.socket.Socket' objects}
#    661409    1.517    0.000    1.517    0.000 {method 'set_value' of 'pandas.index.IndexEngine' objects}
#      2632    0.002    0.000    0.003    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#   1700766    1.074    0.000   11.880    0.000 {method 'sum' of 'numpy.ndarray' objects}
#       470    0.001    0.000    0.001    0.000 {method 'update' of '_hashlib.HASH' objects}
#        94    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       190    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#   1511913    1.629    0.000    1.629    0.000 {numpy.core.multiarray.array}
#         4    0.000    0.000    0.000    0.000 {numpy.core.multiarray.concatenate}
#    755896    1.667    0.000    1.667    0.000 {numpy.core.multiarray.putmask}
#        12    0.000    0.000    0.000    0.000 {pandas.lib.checknull}
#         4    0.000    0.000    0.000    0.000 {pandas.lib.infer_dtype}
#    755908    0.758    0.000    1.886    0.000 {pandas.lib.isscalar}
#         4    0.000    0.000    0.000    0.000 {pandas.lib.list_to_object_array}
#       472    0.000    0.000    0.000    0.000 {posix.getpid}
#        94    0.000    0.000    0.000    0.000 {range}
#        94    0.000    0.000    0.000    0.000 {thread.get_ident}
#       190    0.000    0.000    0.000    0.000 {time.time}
#        94    0.001    0.000    0.001    0.000 {zmq.backend.cython._poll.zmq_poll}

# %%
matrix = data.as_matrix()
matrix = np.array(matrix, dtype=np.float32)

filename_out = 'features/' + INSTRUMENT + '_' + DAY_START + '_' + DAY_END + '.txt'
matrix.tofile(filename_out)

# %%
arr=np.fromfile(filename_out)
arr.shape
# Out:
# (1889740,)

# %%
plt.hist(data['BWIDTH_10'],50)
# Out:
# (array([  7.82350000e+04,   1.33420000e+04,   1.65800000e+03,
#           5.44000000e+02,   2.65000000e+02,   1.33000000e+02,
#           1.02000000e+02,   5.60000000e+01,   4.70000000e+01,
#           3.20000000e+01,   2.50000000e+01,   9.00000000e+00,
#           8.00000000e+00,   4.00000000e+00,   4.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   2.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   2.00000000e+00,
#           0.00000000e+00,   4.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           2.00000000e+00,   2.00000000e+00]),
#  array([  0.        ,   0.48984377,   0.97968754,   1.4695313 ,
#           1.95937507,   2.44921884,   2.93906261,   3.42890638,
#           3.91875014,   4.40859391,   4.89843768,   5.38828145,
#           5.87812522,   6.36796898,   6.85781275,   7.34765652,
#           7.83750029,   8.32734406,   8.81718782,   9.30703159,
#           9.79687536,  10.28671913,  10.7765629 ,  11.26640666,
#          11.75625043,  12.2460942 ,  12.73593797,  13.22578174,
#          13.7156255 ,  14.20546927,  14.69531304,  15.18515681,
#          15.67500058,  16.16484434,  16.65468811,  17.14453188,
#          17.63437565,  18.12421942,  18.61406318,  19.10390695,
#          19.59375072,  20.08359449,  20.57343825,  21.06328202,
#          21.55312579,  22.04296956,  22.53281333,  23.02265709,
#          23.51250086,  24.00234463,  24.4921884 ]),
#  <a list of 50 Patch objects>)

# %%
plt.plot(data.high)
plt.plot(data.low)
#plt.plot(data.SMA_60)
